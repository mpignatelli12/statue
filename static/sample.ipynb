# %% [markdown]
# # Welcome to Statue Notebooks
#
# This is a **markdown** cell. It supports things like [links](https://svelte.dev), *italics*, and **bold** text.
#
# ## Subheader
# You can also use headers.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
1 + 2
# Out:
# 3

# %%
# This is a code cell with no output
def square(x):
    return x * x
